# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing the dataset
df =pd.read_csv(r'c://Users/AB/Desktop/districts_info.csv')
df.head()
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 1         2685       NaN     NaN                NaN              NaN
# 2         4921      Utah  Suburb           [0, 0.2[       [0.2, 0.4[
# 3         3188       NaN     NaN                NaN              NaN
# 4         2238       NaN     NaN                NaN              NaN
#
#   county_connections_ratio    pp_total_raw
# 0                [0.18, 1[  [14000, 16000[
# 1                      NaN             NaN
# 2                [0.18, 1[    [6000, 8000[
# 3                      NaN             NaN
# 4                      NaN             NaN

# %%
de=pd.read_csv(r'c://Users/AB/Desktop/engagement_data/*')
de
# Out:
#               time    lp_id  pct_access  engagement_index
# 0       2020-01-01  93690.0        0.00               NaN
# 1       2020-01-01  17941.0        0.03              0.90
# 2       2020-01-01  65358.0        0.03              1.20
# 3       2020-01-01  98265.0        0.57             37.79
# 4       2020-01-01  59257.0        0.00               NaN
# ...            ...      ...         ...               ...
# 103998  2020-12-31  68845.0        0.00               NaN
# 103999  2020-12-31  28324.0        0.00               NaN
# 104000  2020-12-31  64947.0        0.00               NaN
# 104001  2020-12-31  13496.0        0.03              0.26
# 104002  2020-12-31  79673.0        0.03              0.26
#
# [104003 rows x 4 columns]

# %%
dp =pd.read_csv(r'c://Users/AB/Desktop/products_info.csv')
dp.head()
# Out:
#    lp_id                           URL  Product Name  Provider/Company Name  \
# 0  13117    https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933          https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479         https://www.abcya.com        ABCya!         ABCya.com, LLC
# 3  92993         http://www.aleks.com/         ALEKS    McGraw-Hill PreK-12
# 4  73104  https://www.achieve3000.com/   Achieve3000            Achieve3000
#
#             Sector(s)                         Primary Essential Function
# 0             PreK-12                    LC - Digital Learning Platforms
# 1             PreK-12                    LC - Digital Learning Platforms
# 2             PreK-12  LC - Sites, Resources & Reference - Games & Si...
# 3  PreK-12; Higher Ed                    LC - Digital Learning Platforms
# 4             PreK-12                    LC - Digital Learning Platforms

# %%
#Let us get some basic insight on our columns
#and understand their properties and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   district_id               233 non-null    int64
#  1   state                     176 non-null    object
#  2   locale                    176 non-null    object
#  3   pct_black/hispanic        176 non-null    object
#  4   pct_free/reduced          148 non-null    object
#  5   county_connections_ratio  162 non-null    object
#  6   pp_total_raw              118 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 12.9+ KB

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      district_id  state  locale  pct_black/hispanic  pct_free/reduced  \
# 0          False  False   False               False             False
# 1          False   True    True                True              True
# 2          False  False   False               False             False
# 3          False   True    True                True              True
# 4          False   True    True                True              True
# ..           ...    ...     ...                 ...               ...
# 228        False  False   False               False             False
# 229        False  False   False               False              True
# 230        False  False   False               False             False
# 231        False  False   False               False             False
# 232        False  False   False               False             False
#
#      county_connections_ratio  pp_total_raw
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   lp_id                       372 non-null    int64
#  1   URL                         372 non-null    object
#  2   Product Name                372 non-null    object
#  3   Provider/Company Name       371 non-null    object
#  4   Sector(s)                   352 non-null    object
#  5   Primary Essential Function  352 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB

# %%
result = pd.concat([df, de], axis=1)

# %%
result.head()
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0       8815.0  Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 1       2685.0       NaN     NaN                NaN              NaN
# 2       4921.0      Utah  Suburb           [0, 0.2[       [0.2, 0.4[
# 3       3188.0       NaN     NaN                NaN              NaN
# 4       2238.0       NaN     NaN                NaN              NaN
#
#   county_connections_ratio    pp_total_raw        time    lp_id  pct_access  \
# 0                [0.18, 1[  [14000, 16000[  2020-01-01  93690.0        0.00
# 1                      NaN             NaN  2020-01-01  17941.0        0.03
# 2                [0.18, 1[    [6000, 8000[  2020-01-01  65358.0        0.03
# 3                      NaN             NaN  2020-01-01  98265.0        0.57
# 4                      NaN             NaN  2020-01-01  59257.0        0.00
#
#    engagement_index
# 0               NaN
# 1              0.90
# 2              1.20
# ...

# %%
result_join = dp.merge(de, on='lp_id', how='left')

# %%
result_join
# Out:
#        lp_id                             URL                  Product Name  \
# 0      13117      https://www.splashmath.com                   SplashLearn
# 1      13117      https://www.splashmath.com                   SplashLearn
# 2      13117      https://www.splashmath.com                   SplashLearn
# 3      13117      https://www.splashmath.com                   SplashLearn
# 4      13117      https://www.splashmath.com                   SplashLearn
# ...      ...                             ...                           ...
# 63357  87841             http://edpuzzle.com  Edpuzzle - Free (Basic Plan)
# 63358  87841             http://edpuzzle.com  Edpuzzle - Free (Basic Plan)
# 63359  87841             http://edpuzzle.com  Edpuzzle - Free (Basic Plan)
# 63360  87841             http://edpuzzle.com  Edpuzzle - Free (Basic Plan)
# 63361  36254  http://www.truenorthlogic.com/              True North Logic
#
# ...

# %% [markdown]
# # Analysis on Products for digital learning

# %%
dp
# Out:
#      lp_id                                        URL  \
# 0    13117                 https://www.splashmath.com
# 1    66933                       https://abcmouse.com
# 2    50479                      https://www.abcya.com
# 3    92993                      http://www.aleks.com/
# 4    73104               https://www.achieve3000.com/
# ..     ...                                        ...
# 367  88065                        https://dochub.com/
# 368  37805            http://google.com/slides/about/
# 369  32555  http://www.innersloth.com/gameAmongUs.php
# 370  87841                        http://edpuzzle.com
# 371  36254             http://www.truenorthlogic.com/
#
#                      Product Name  Provider/Company Name  \
# 0                     SplashLearn          StudyPad Inc.
# 1                    ABCmouse.com  Age of Learning, Inc
# 2                          ABCya!         ABCya.com, LLC
# 3                           ALEKS    McGraw-Hill PreK-12
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   lp_id                       372 non-null    int64
#  1   URL                         372 non-null    object
#  2   Product Name                372 non-null    object
#  3   Provider/Company Name       371 non-null    object
#  4   Sector(s)                   352 non-null    object
#  5   Primary Essential Function  352 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB

# %%
dp.isnull().sum()
# Out:
# lp_id                          0
# URL                            0
# Product Name                   0
# Provider/Company Name          1
# Sector(s)                     20
# Primary Essential Function    20
# dtype: int64

# %% [markdown]
# There is no much null values so no need to drop them.
